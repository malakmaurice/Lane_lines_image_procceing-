# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from IPython.display import HTML, Video
from moviepy.editor import VideoFileClip
from PerspectiveTransformation import *
from Lanelines import *
from main import *

# %%
images = []
images.append('test_images/straight_lines1.jpg')
images.append('test_images/straight_lines2.jpg')
images.append('test_images/test1.jpg')
images.append('test_images/test2.jpg')
images.append('test_images/test3.jpg')
images.append('test_images/test4.jpg')
images.append('test_images/test5.jpg')
images.append('test_images/test6.jpg')
out_folder = "output_images/"
findLaneLines = FindLaneLines()

# %%
findLaneLines.process_image(images[0], out_folder+'out1.jpg')
img=mpimg.imread(out_folder+'out1.jpg')
plt.imshow(img)

# %%
findLaneLines.process_image(images[1], out_folder+'out2.jpg')
img=mpimg.imread(out_folder+'out2.jpg')
plt.imshow(img)

# %%
findLaneLines.process_image(images[2], out_folder+'out3.jpg')
img=mpimg.imread(out_folder+'out3.jpg')
plt.imshow(img)

# %%
findLaneLines.process_image(images[3], out_folder+'out4.jpg')
img=mpimg.imread(out_folder+'out4.jpg')
plt.imshow(img)

# %%
findLaneLines.process_image(images[4], out_folder+'out5.jpg')
img=mpimg.imread(out_folder+'out5.jpg')
plt.imshow(img)

# %%
findLaneLines.process_image(images[5], out_folder+'out6.jpg')
img=mpimg.imread(out_folder+'out6.jpg')
plt.imshow(img)

# %%
findLaneLines.process_image(images[6], out_folder+'out7.jpg')
img=mpimg.imread(out_folder+'out7.jpg')
plt.imshow(img)

# %%
findLaneLines.process_image(images[7], out_folder+'out8.jpg')
img=mpimg.imread(out_folder+'out8.jpg')
plt.imshow(img)
