# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from IPython.display import HTML, Video
from moviepy.editor import VideoFileClip
from PerspectiveTransformation import *
from Lanelines import *
from main import *

# %%
images = []
images.append('test_images/test1.jpg')
images.append('test_images/test2.jpg')
images.append('test_images/test3.jpg')
images.append('test_images/test4.jpg')
images.append('test_images/test5.jpg')
images.append('test_images/test6.jpg')

# %%
findLaneLines = FindLaneLines()
findLaneLines.process_image(images[0], 'out1.jpg')
img=mpimg.imread('out1.jpg')
plt.imshow(img)

# %%
findLaneLines = FindLaneLines()
findLaneLines.process_image(images[1], 'out2.jpg')
img=mpimg.imread('out2.jpg')
plt.imshow(img)

# %%
findLaneLines = FindLaneLines()
findLaneLines.process_image(images[2], 'out3.jpg')
img=mpimg.imread('out3.jpg')
plt.imshow(img)

# %%
findLaneLines = FindLaneLines()
findLaneLines.process_image(images[3], 'out4.jpg')
img=mpimg.imread('out4.jpg')
plt.imshow(img)

# %%
findLaneLines = FindLaneLines()
findLaneLines.process_image(images[4], 'out5.jpg')
img=mpimg.imread('out5.jpg')
plt.imshow(img)

# %%
findLaneLines = FindLaneLines()
findLaneLines.process_image(images[5], 'out6.jpg')
img=mpimg.imread('out6.jpg')
plt.imshow(img)
